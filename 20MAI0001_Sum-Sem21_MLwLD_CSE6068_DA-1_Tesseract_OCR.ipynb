# %% [markdown]
# # Machine Learning with Large Datasets : CSE6068 : Digital Assignment -1
# Summer-Semester 2020-21 , SCOPE , VIT Vellore

# %% [markdown]
# # Assignment Topic :- Tesseract OCR

# %% [markdown]
# # Implemented By: 20MAI0001 - NIHARIKA MAITRA ,
#
# M.Tech. Computer Science and Engineering
#     with Specialization in Artificial Intelligence and Machine Learning

# %% [markdown]
# # Under the esteemed Guidance of : Dr. SRIMATHI C , Associate Professor Sr.
#     Department of Information Security ,SCOPE , VIT Vellore

# %% [markdown]
# # Team Mates :
#         Jency
#         Subham
#         Kshitija
#
#
# Git Repo link :

# %% [markdown]
# # Implementation using 'pytesseract'  :-
#
# Demonstration of the basic main applications / functioning of Tesseract OCR through implementation of 5 Use-Cases with the help of 'pytesseract' Module/Library of Python , in Anaconda ( Jupyter Notebook )Platform , to Implement : Text , Number type od data Extraction and  Generation as Output from different Input Image resources containing Text and Numeric elements inside them :

# %%
import pytesseract

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\NRika\anaconda3\envs\tesseract\Library\bin\tesseract.exe'

# %% [markdown]
# # Text and Numeric Data Extraction from a Poster Image :-

# %% [markdown]
# # Original Input Image : A Poster on : 'World Environment Day 2021'

# %% [markdown]
# ![test_image.jpg](attachment:test_image.jpg)

# %% [markdown]
# # Resultant Output : Generation and Display by Fetching all the Text and Numeric Data present inside the Input Poster Image

# %%
text_from_image = pytesseract.image_to_string(Image.open('test_image.jpg'))
print(text_from_image)
# Out:
# If we have a healthy environment around
# us then everything else is going
# e to fallin place
#
#
#
#
# Happy World
# Environment
# “* Day
#
# 2021

# %% [markdown]
# #  AlphaNumeric Data Extraction from Car Number Plate Image:-

# %% [markdown]
# # Input Image:

# %% [markdown]
# ![img3.png](attachment:img3.png)

# %% [markdown]
# # Resultant  Output : The Particular AlphaNumeric Value Extracted from the Car Number Plate Input Image:

# %%
num_from_image = pytesseract.image_to_string(Image.open('img3.png'))
print(num_from_image)
# Out:
# MH12DE1433

# %% [markdown]
# # Text and Numeric Data Extraction from the Image of an Invoice :-

# %% [markdown]
# # Input Invoice Image:-

# %% [markdown]
# ![invoice1.png](attachment:invoice1.png)

# %% [markdown]
# # Resultant Output : Generation and Display by Fetching all the Text and Numeric Data present inside  the Input Invoice Image :-

# %%
text_from_invo = pytesseract.image_to_string(Image.open('invoice1.png'))
print(text_from_invo)
# Out:
#
#
# COMPANY NAME
#
#
#
# Street Address
# City, ST ZIP Code
# E-mal
# Phone No.
#
# Custome! VAT No.
#
# Name
#
# Street Address Invoice No.
#
# City, ST ZIP Code Invoice Date:
#
# E-mail Payment Tems 30 Days
#
# Phone No.
#
# Commission Invoice
#
#
#
# Price wiout Price with Total wout_ Total with Commission
#
# Date Descrstion ty commission commission commission commision Amount
#
# Net Amount
#
#
#
# 106.04 (Case ofsoda 100 50 $  50.00/$ 5250 $ 5,000.00 $ 525000 $ 25000 $ 5,000.00
#
# 50 100 |$ 100.00 § 110.00 $ 5,000.00 $ 5,500.00 § 500.00 § 5,000.00

# %% [markdown]
# # Date and Time type of Data Extraction from a Digitized Date-Time Image :-

# %% [markdown]
# # Input Date-Time Image :

# %% [markdown]
# ![dc6.png](attachment:dc6.png)

# %% [markdown]
# # Resultant Output : Generation and Display by Fetching all the Numeric ( i.e, Date and Time ) type of Data present inside the Input Date-Time Image :-

# %%
dt_from_image = pytesseract.image_to_string(Image.open('dc-5.png'))
print(dt_from_image)
# Out:
# ST0] a1 6 [= \) MPL
#
# 11:33
#
# 6 Jan 2019

# %% [markdown]
# # Text , Numeric , Date-Time , Special Characters  type of Data Extraction from a Screenshot Image of exchange of Chats on a Social Media Platform  :-

# %% [markdown]
# # Input Chat Screenshot Image :

# %% [markdown]
# ![img5.jpeg](attachment:img5.jpeg)

# %% [markdown]
# # Resultant Output : Generation and Display by Fetching all the Text , Numeric , Date-Time , Special Characters type of Data present inside the Input Chat Screenshot Image :-

# %%
text_from_ss = pytesseract.image_to_string(Image.open('img5.jpeg'))
print(text_from_ss)
# Out:
# @eee0 Vodafone > 9:45 PM
# Jennifer
# < Chats
# Hey there......
#
# how do you do....
#
# long time no seen...
#
# oh is that so ... let's party !
#
# Party? When?
#
# Tomorrow ... 8 PM
# Be on time .... Will enjoy
#
# wowwww
#
# tell everyone ... it will be fun
#
# see ya then
#
# yes .... bye ... sleep tight
#
# @
#
# e070 =
#
# <
